# %% [markdown]
# Comparemos la evolución temporal para los casos de difusión espacial y aleatoria:

# %%
# %pylab inline
from haggerstrand.diffusion import SimpleDiffusion
s = SimpleDiffusion(50,50,9,20,[(20,20)],0.3,20)
s.spatial_diffusion()
tmp_s = s.time_series
s.random_diffusion()
tmp_r = s.time_series
plt.plot(tmp_s)
plt.plot(tmp_r,'r')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# acabé
# Hay 30761 adoptantes de un total de 50000 habitantes
# El total de iteraciones realizadas es 20
# acabé
# Hay 49359 adoptantes de un total de 50000 habitantes
# El total de iteraciones realizadas es 20
